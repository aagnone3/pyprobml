# %%
import os
from os import path
import numpy as np
import pandas as pd
import pymc3 as mc
import theano
import seaborn as sns

np.random.seed(123)
# %matplotlib inline

# %%
import pymc3.examples.data as data_dir
data_dir = data_dir.__path__._path[0]
df = pd.read_csv(path.join(data_dir, "radon.csv"))
df.shape
# Out:
# (919, 30)

# %%
df.head()
# Out:
#    Unnamed: 0   idnum state state2  stfips    zip  region  typebldg  floor  \
# 0           0  5081.0    MN     MN    27.0  55735     5.0       1.0    1.0
# 1           1  5082.0    MN     MN    27.0  55748     5.0       1.0    0.0
# 2           2  5083.0    MN     MN    27.0  55748     5.0       1.0    0.0
# 3           3  5084.0    MN     MN    27.0  56469     5.0       1.0    0.0
# 4           4  5085.0    MN     MN    27.0  55011     3.0       1.0    0.0
#
#    room    ...     pcterr        adjwt  dupflag  zipflag  cntyfips  county  \
# 0   3.0    ...        9.7  1146.499190      1.0      0.0       1.0  AITKIN
# 1   4.0    ...       14.5   471.366223      0.0      0.0       1.0  AITKIN
# 2   4.0    ...        9.6   433.316718      0.0      0.0       1.0  AITKIN
# 3   4.0    ...       24.3   461.623670      0.0      0.0       1.0  AITKIN
# 4   4.0    ...       13.8   433.316718      0.0      0.0       3.0   ANOKA
#
#       fips      Uppm  county_code  log_radon
# 0  27001.0  0.502054            0   0.832909
# 1  27001.0  0.502054            0   0.832909
# 2  27001.0  0.502054            0   1.098612
# 3  27001.0  0.502054            0   0.095310
# 4  27003.0  0.428565            1   1.163151
#
# [5 rows x 30 columns]

# %%
county_names = df.county.unique()
county_idx = df.county_code.values
n_counties = len(county_names)
df['log_radon'] = df['log_radon'].astype(theano.config.floatX)
X = df[['county', 'log_radon', 'floor']]

# %%
traces = dict()
for county_name in county_names:
    # get data for the current county
    X_one = X.loc[X.county == county_name].reset_index(drop=True)
    
    log_radon = X_one.log_radon
    floor = X_one.floor.values
    
    with pm.Model() as one_model:
        # intercept prior
        intercept = pm.Normal('intercept', mu=0, sd=1)
        # slope prior
        slope = pm.Normal('slope', mu=0, sd=1)
        # model error prior
        eps = pm.HalfCauchy('eps', beta=1)
        
        # define the model
        model_est = intercept + slope * floor
        
        # define the data likelihood
        y_lik = pm.Normal('y_lik', mu=model_est, sd=eps, observed=log_radon)
        
        # sample with the model
        trace = pm.sample(progressbar=True, n_init=100, draws=100)
        
    traces[county_name] = trace
# Out:
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 3969.34draws/s]
# The acceptance probability does not match the target. It is 0.886691850698103, but should be close to 0.8. Try to increase the number of tuning steps.
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 4188.49draws/s]
# The acceptance probability does not match the target. It is 0.879785382540666, but should be close to 0.8. Try to increase the number of tuning steps.
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 3139.69draws/s]
# The gelman-rubin statistic is larger than 1.05 for some parameters. This indicates slight problems during sampling.
# The number of effective samples is smaller than 25% for some parameters.
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 3543.18draws/s]
# The acceptance probability does not match the target. It is 0.8894562629258037, but should be close to 0.8. Try to increase the number of tuning steps.
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 3445.48draws/s]
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 3368.87draws/s]
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 4232.24draws/s]
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 3467.16draws/s]
# There were 2 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.7209921228102643, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.699206594138382, but should be close to 0.8. Try to increase the number of tuning steps.
# There was 1 divergence after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.6821237743110676, but should be close to 0.8. Try to increase the number of tuning steps.
# The gelman-rubin statistic is larger than 1.05 for some parameters. This indicates slight problems during sampling.
# The number of effective samples is smaller than 25% for some parameters.
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 3837.33draws/s]
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 3515.59draws/s]
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 3587.71draws/s]
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 3444.84draws/s]
# The acceptance probability does not match the target. It is 0.8826495230792287, but should be close to 0.8. Try to increase the number of tuning steps.
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 3744.63draws/s]
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 3826.73draws/s]
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 3291.21draws/s]
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 3336.65draws/s]
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 3991.74draws/s]
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 4156.50draws/s]
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 3481.43draws/s]
# The acceptance probability does not match the target. It is 0.88916122155162, but should be close to 0.8. Try to increase the number of tuning steps.
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 2628.46draws/s]
# The number of effective samples is smaller than 25% for some parameters.
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 3937.28draws/s]
# The acceptance probability does not match the target. It is 0.8967544675306929, but should be close to 0.8. Try to increase the number of tuning steps.
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 3810.08draws/s]
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 3025.48draws/s]
# There was 1 divergence after tuning. Increase `target_accept` or reparameterize.
# There were 7 divergences after tuning. Increase `target_accept` or reparameterize.
# There was 1 divergence after tuning. Increase `target_accept` or reparameterize.
# There were 3 divergences after tuning. Increase `target_accept` or reparameterize.
# The number of effective samples is smaller than 25% for some parameters.
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 3883.82draws/s]
# The acceptance probability does not match the target. It is 0.8918857814370431, but should be close to 0.8. Try to increase the number of tuning steps.
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 3605.59draws/s]
# The acceptance probability does not match the target. It is 0.8943382554076559, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8899543087976051, but should be close to 0.8. Try to increase the number of tuning steps.
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 3719.68draws/s]
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 3635.65draws/s]
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 3387.38draws/s]
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 3390.26draws/s]
# The number of effective samples is smaller than 25% for some parameters.
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 3665.11draws/s]
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 3667.45draws/s]
# The number of effective samples is smaller than 25% for some parameters.
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 3792.33draws/s]
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 3092.62draws/s]
# The acceptance probability does not match the target. It is 0.7086331351160641, but should be close to 0.8. Try to increase the number of tuning steps.
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 3157.71draws/s]
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 2957.42draws/s]
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 2504.25draws/s]
# There was 1 divergence after tuning. Increase `target_accept` or reparameterize.
# There were 3 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 8 divergences after tuning. Increase `target_accept` or reparameterize.
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 3723.59draws/s]
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 3051.30draws/s]
# The acceptance probability does not match the target. It is 0.569947582756246, but should be close to 0.8. Try to increase the number of tuning steps.
# The gelman-rubin statistic is larger than 1.05 for some parameters. This indicates slight problems during sampling.
# The number of effective samples is smaller than 25% for some parameters.
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 2847.07draws/s]
# The acceptance probability does not match the target. It is 0.7211760863430312, but should be close to 0.8. Try to increase the number of tuning steps.
# The number of effective samples is smaller than 25% for some parameters.
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 3097.85draws/s]
# The number of effective samples is smaller than 25% for some parameters.
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 2897.15draws/s]
# The acceptance probability does not match the target. It is 0.8937612677773977, but should be close to 0.8. Try to increase the number of tuning steps.
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 2937.66draws/s]
# There were 5 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.7123562412343415, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 7 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.7178126040790643, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 8 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.7188498771216206, but should be close to 0.8. Try to increase the number of tuning steps.
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 2737.14draws/s]
# The acceptance probability does not match the target. It is 0.6234170606071666, but should be close to 0.8. Try to increase the number of tuning steps.
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 3221.61draws/s]
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 3345.69draws/s]
# The acceptance probability does not match the target. It is 0.8877005343039286, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8847666086656408, but should be close to 0.8. Try to increase the number of tuning steps.
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 3204.90draws/s]
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 3067.16draws/s]
# There was 1 divergence after tuning. Increase `target_accept` or reparameterize.
# There was 1 divergence after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.9075456617144746, but should be close to 0.8. Try to increase the number of tuning steps.
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 3501.38draws/s]
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 3249.47draws/s]
# The acceptance probability does not match the target. It is 0.899729818070953, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.9029933370212412, but should be close to 0.8. Try to increase the number of tuning steps.
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 2916.47draws/s]
# There were 3 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.8992371454744114, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 2 divergences after tuning. Increase `target_accept` or reparameterize.
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 3198.81draws/s]
# The acceptance probability does not match the target. It is 0.8819801130353535, but should be close to 0.8. Try to increase the number of tuning steps.
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 2440.46draws/s]
# The number of effective samples is smaller than 25% for some parameters.
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 2696.13draws/s]
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 3286.35draws/s]
# The acceptance probability does not match the target. It is 0.8829968637731829, but should be close to 0.8. Try to increase the number of tuning steps.
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 3363.17draws/s]
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 3009.81draws/s]
# The acceptance probability does not match the target. It is 0.9149360181309698, but should be close to 0.8. Try to increase the number of tuning steps.
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 2576.49draws/s]
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 3205.53draws/s]
# The acceptance probability does not match the target. It is 0.8807041316227511, but should be close to 0.8. Try to increase the number of tuning steps.
# The number of effective samples is smaller than 25% for some parameters.
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 2890.14draws/s]
# There was 1 divergence after tuning. Increase `target_accept` or reparameterize.
# There was 1 divergence after tuning. Increase `target_accept` or reparameterize.
# The gelman-rubin statistic is larger than 1.05 for some parameters. This indicates slight problems during sampling.
# The number of effective samples is smaller than 25% for some parameters.
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:01<00:00, 1951.64draws/s]
# There were 2 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 4 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 8 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.610920764765046, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 2 divergences after tuning. Increase `target_accept` or reparameterize.
# The gelman-rubin statistic is larger than 1.05 for some parameters. This indicates slight problems during sampling.
# The number of effective samples is smaller than 25% for some parameters.
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 3151.89draws/s]
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:01<00:00, 2310.41draws/s]
# The number of effective samples is smaller than 25% for some parameters.
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:01<00:00, 2122.76draws/s]
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 3280.31draws/s]
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 3096.04draws/s]
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 3453.90draws/s]
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 3544.15draws/s]
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 3111.33draws/s]
# The acceptance probability does not match the target. It is 0.8881449652982946, but should be close to 0.8. Try to increase the number of tuning steps.
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 3282.61draws/s]
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 3487.40draws/s]
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 3129.02draws/s]
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 3096.91draws/s]
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 2576.73draws/s]
# There were 2 divergences after tuning. Increase `target_accept` or reparameterize.
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:01<00:00, 2142.76draws/s]
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:01<00:00, 1986.70draws/s]
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 2770.89draws/s]
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 3218.57draws/s]
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 3479.99draws/s]
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 3672.14draws/s]
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 2812.93draws/s]
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 2479.72draws/s]
# There were 4 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.6056135142022424, but should be close to 0.8. Try to increase the number of tuning steps.
# There was 1 divergence after tuning. Increase `target_accept` or reparameterize.
# There was 1 divergence after tuning. Increase `target_accept` or reparameterize.
# There was 1 divergence after tuning. Increase `target_accept` or reparameterize.
# The number of effective samples is smaller than 25% for some parameters.
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:01<00:00, 2115.82draws/s]
# There was 1 divergence after tuning. Increase `target_accept` or reparameterize.
# There were 2 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 3 divergences after tuning. Increase `target_accept` or reparameterize.
# There was 1 divergence after tuning. Increase `target_accept` or reparameterize.
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 2460.49draws/s]
# The acceptance probability does not match the target. It is 0.8832838128884238, but should be close to 0.8. Try to increase the number of tuning steps.
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 2913.40draws/s]
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, slope, intercept]
# Sampling 4 chains: 100%|██████████| 2400/2400 [00:00<00:00, 2740.32draws/s]
# There were 2 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 7 divergences after tuning. Increase `target_accept` or reparameterize.
# There was 1 divergence after tuning. Increase `target_accept` or reparameterize.

# %%
with pm.Model() as hierarchical_model:
    # hyper-priors
    mu_alpha = pm.Normal('mu_alpha', mu=0, sd=1)
    mu_beta = pm.Normal('mu_beta', mu=0, sd=1)
    sigma_alpha = pm.HalfCauchy('sigma_alpha', beta=1)
    sigma_beta = pm.HalfCauchy('sigma_beta', beta=1)
    
    # the intercepts (alphas) for each county
    alphas = pm.Normal('county_alphas', mu=mu_alpha, sd=sigma_alpha, shape=len(county_names))
    # the slopes (betas) for each county
    betas = pm.Normal('county_betas', mu=mu_beta, sd=sigma_beta, shape=len(county_names))
    
    # the hierarchical model
    radon_est = alphas[df.county_code.values] + betas[df.county_code.values] * df.floor.values
    
    # the model error
    eps = pm.HalfCauchy('eps', beta=1)
    
    # define the data likelihood under this model
    y_lik = pm.Normal('y_lik', mu=radon_est, sd=eps, observed=df.log_radon.values)

with hierarchical_model:
    hierarchical_trace = pm.sample()
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [eps, county_betas, county_alphas, sigma_beta, sigma_alpha, mu_beta, mu_alpha]
# Sampling 4 chains: 100%|██████████| 4000/4000 [00:08<00:00, 465.31draws/s]
# There was 1 divergence after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.6903845264606879, but should be close to 0.8. Try to increase the number of tuning steps.
# There was 1 divergence after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.9554717005910119, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 164 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.49970794249328465, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8831672021972317, but should be close to 0.8. Try to increase the number of tuning steps.
# The gelman-rubin statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The estimated number of effective samples is smaller than 200 for some parameters.
